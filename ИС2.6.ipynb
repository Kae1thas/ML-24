# %% [markdown]
# Подключем необходимые библиотеки:

# %%
from __future__ import division, print_function
import numpy as np
import pandas as pd
import scipy
from google.colab import files
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %% [markdown]
# Проведем первичное обследование набора данных. Выполним
# загрузку данных (рис. 6.2). Такое представление обучающей и тестовой
# выборок не дает осмысленного представления о структуре данных, вывод
# тяжело читается.

# %%
train_df = pd.read_csv('howpop_train.csv')
test_df = pd.read_csv('howpop_test.csv')
print('//////////////////////////////////////////')
print(train_df.head())
print('//////////////////////////////////////////')
print(test_df.head()) # Рис 6.2
# Out:
# //////////////////////////////////////////
#                                 url        domain  post_id  \
# 0  https://habrahabr.ru/post/18284/  habrahabr.ru    18284
# 1  https://habrahabr.ru/post/18285/  habrahabr.ru    18285
# 2  https://habrahabr.ru/post/18286/  habrahabr.ru    18286
# 3  https://habrahabr.ru/post/18291/  habrahabr.ru    18291
# 4  https://geektimes.ru/post/18294/  geektimes.ru    18294
#
#              published      author     flow  polling  content_len  \
# 0  2008-01-01 18:19:00      @Tapac  develop    False       4305.0
# 1  2008-01-01 18:30:00  @DezmASter   design    False       7344.0
# 2  2008-01-01 18:34:00  @DezmASter   design    False       8431.0
# 3  2008-01-02 01:32:00    @Taoorus   design    False       5662.0
# 4  2008-01-02 14:34:00    @dennydo      NaN    False       3706.0
#
#                                                title  comments  favs   views  \
# 0     Новогодний подарок блоггерам — WordPress 2.3.2       0.0   0.0   236.0
# 1  Сумасшедшие яйца, или сервис для отслеживания ...       1.0   1.0   353.0
# 2  Сумасшедшие яйца, или сервис для отслеживания ...      47.0  72.0  1200.0
# 3     Сглаживание шрифтов, и субпиксельная отрисовка     102.0  36.0  5700.0
# 4                      Почему мне не нравится iPhone     230.0   6.0  1400.0
#
#    votes_plus  votes_minus  views_lognorm  favs_lognorm  comments_lognorm
# 0         0.0          0.0      -0.792687     -1.344075         -2.436871
# 1         1.0          0.0      -0.485214     -0.831946         -1.873193
# 2        45.0          5.0       0.446090      1.794023          0.574656
# 3        72.0          3.0       1.627469      1.300050          1.167375
# 4        73.0         15.0       1.362397      0.961094          2.020356
# //////////////////////////////////////////
#                                                  url        domain  post_id  \
# 0                  https://habrahabr.ru/post/314080/  habrahabr.ru   314080
# 1    https://habrahabr.ru/company/plesk/blog/313732/  habrahabr.ru   313732
# 2    https://habrahabr.ru/company/etagi/blog/314000/  habrahabr.ru   314000
# 3   https://habrahabr.ru/company/knopka/blog/314030/  habrahabr.ru   314030
# 4  https://geektimes.ru/company/audiomania/blog/2...  geektimes.ru   282058
#
#              published   author       flow  polling  content_len  \
# 0  2016-11-01 01:05:00  @fsou11    develop     True        20132
# 1  2016-11-01 05:42:00      NaN  marketing    False        12389
# 2  2016-11-01 08:33:00      NaN      admin    False        72839
# 3  2016-11-01 09:00:00      NaN    develop    False        29572
# 4  2016-11-01 09:44:00      NaN        NaN    False         9642
#
#                                                title
# 0                 Опыт использования MassTransit 3.0
# 1              Геймификация форума на движке XenForo
# 2  Кластер высокой доступности на postgresql 9.6 ...
# 3  Как перестать бояться и полюбить синтаксически...
# 4  Мифы и реальность: Что нужно знать о современн...

# %% [markdown]
# Трансформируем вывод следующим образом (рис. 6.3): в
# методе head() будем выводить одну строку, а также транспонируем вывод.

# %%
train_df = pd.read_csv('howpop_train.csv')
test_df = pd.read_csv('howpop_test.csv')
print('//////////////////////////////////////////')
print(train_df.head(1).T)
print('//////////////////////////////////////////')
print(test_df.head(1).T)
# Out:
# //////////////////////////////////////////
#                                                                0
# url                             https://habrahabr.ru/post/18284/
# domain                                              habrahabr.ru
# post_id                                                    18284
# published                                    2008-01-01 18:19:00
# author                                                    @Tapac
# flow                                                     develop
# polling                                                    False
# content_len                                                 4305
# title             Новогодний подарок блоггерам — WordPress 2.3.2
# comments                                                       0
# favs                                                           0
# views                                                        236
# votes_plus                                                   0.0
# votes_minus                                                  0.0
# views_lognorm                                          -0.792687
# favs_lognorm                                           -1.344075
# comments_lognorm                                       -2.436871
# //////////////////////////////////////////
#                                               0
# url           https://habrahabr.ru/post/314080/
# domain                             habrahabr.ru
# post_id                                  314080
# published                   2016-11-01 01:05:00
# author                                  @fsou11
# flow                                    develop
# polling                                    True
# content_len                               20132
# title        Опыт использования MassTransit 3.0

# %% [markdown]
# Определим размер выборок:

# %%
print('Тестовый набор: \t', test_df.shape)
print('Обучающая выборка: \t', train_df.shape)
# Out:
# Тестовый набор: 	 (3990, 9)
# Обучающая выборка: 	 (134137, 17)

# %% [markdown]
# Получим общую информацию по фрейму:

# %%
print(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134137 entries, 0 to 134136
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   url               134137 non-null  object
#  1   domain            134137 non-null  object
#  2   post_id           134137 non-null  int64
#  3   published         134137 non-null  object
#  4   author            97657 non-null   object
#  5   flow              97048 non-null   object
#  6   polling           134137 non-null  bool
#  7   content_len       134137 non-null  int64
#  8   title             134137 non-null  object
#  9   comments          134137 non-null  int64
#  10  favs              134137 non-null  int64
#  11  views             134137 non-null  int64
#  12  votes_plus        133566 non-null  float64
#  13  votes_minus       133566 non-null  float64
#  14  views_lognorm     134137 non-null  float64
#  15  favs_lognorm      134137 non-null  float64
#  16  comments_lognorm  134137 non-null  float64
# dtypes: bool(1), float64(5), int64(5), object(6)
# memory usage: 16.5+ MB
# None

# %% [markdown]
# Рассмотрим, каким образом упорядочены данные в train_df по
# временной оси (по published). Для этого используем код (рис. 6.7). Данные
# упорядочены по полю published (рис. 6.8).

# %%
# копируем столбец данных published
ser_data = train_df['published'].apply(lambda ts: pd.to_datetime(ts))
print('Ряд с датами столбца published')
print(ser_data.head())
print('Размер объекта Series: ', train_df.shape)
ser_data.apply(lambda el: el.value).plot()
# Out:
# Ряд с датами столбца published
# 0   2008-01-01 18:19:00
# 1   2008-01-01 18:30:00
# 2   2008-01-01 18:34:00
# 3   2008-01-02 01:32:00
# 4   2008-01-02 14:34:00
# Name: published, dtype: datetime64[ns]
# Размер объекта Series:  (134137, 17)
# <Axes: >

# %% [markdown]
# Продолжим анализировать набор данных и определим,
# существует ли корреляция между отдельными признаками. Для этого
# воспользуемся методом pandas.DataFrame.corr(). Вызвав реализацию функции
# по умолчанию train_df.corr(), получим коэффициенты корреляции.

# %%
# Оставляем только числовые столбцы
numeric_train_df = train_df.select_dtypes(include=['number'])

# Вычисляем корреляцию
corr = numeric_train_df.corr()
corr
# Out:
#                    post_id  content_len  comments      favs     views  \
# post_id           1.000000     0.241384 -0.147763  0.089313  0.132385
# content_len       0.241384     1.000000 -0.023544  0.308194  0.204101
# comments         -0.147763    -0.023544  1.000000  0.164166  0.290035
# favs              0.089313     0.308194  0.164166  1.000000  0.634304
# views             0.132385     0.204101  0.290035  0.634304  1.000000
# votes_plus       -0.187885     0.068779  0.613961  0.416241  0.396849
# votes_minus      -0.235594    -0.078686  0.457638  0.062877  0.128654
# views_lognorm    -0.010376     0.246063  0.349568  0.456097  0.585105
# favs_lognorm     -0.005845     0.356481  0.278942  0.587982  0.406782
# comments_lognorm -0.001605     0.073132  0.662740  0.263239  0.326427
#
#                   votes_plus  votes_minus  views_lognorm  favs_lognorm  \
# post_id            -0.187885    -0.235594      -0.010376     -0.005845
# content_len         0.068779    -0.078686       0.246063      0.356481
# comments            0.613961     0.457638       0.349568      0.278942
# favs                0.416241     0.062877       0.456097      0.587982
# views               0.396849     0.128654       0.585105      0.406782
# votes_plus          1.000000     0.464168       0.414232      0.449712
# votes_minus         0.464168     1.000000       0.146609      0.088226
# views_lognorm       0.414232     0.146609       1.000000      0.688811
# favs_lognorm        0.449712     0.088226       0.688811      1.000000
# comments_lognorm    0.525081     0.355458       0.546530      0.479476
#
#                   comments_lognorm
# post_id                  -0.001605
# content_len               0.073132
# comments                  0.662740
# favs                      0.263239
# views                     0.326427
# votes_plus                0.525081
# votes_minus               0.355458
# views_lognorm             0.546530
# favs_lognorm              0.479476
# comments_lognorm          1.000000

# %% [markdown]
# По данной матрице необходимо определить коррелирующие рпизнаки
# (с коэффициентом корреляции больше 0.9). Искать такие значения по
# представленной матрице – достаточно сложная задача, которая повлечет
# ошибки, поэтому представим матрицу корреляции в удобном для анализа
# виде:

# %%
corr[corr>0.9].replace({np.nan : ''})
# Out:
#                  post_id content_len comments favs views votes_plus  \
# post_id              1.0
# content_len                      1.0
# comments                                  1.0
# favs                                           1.0
# views                                                1.0
# votes_plus                                                      1.0
# votes_minus
# views_lognorm
# favs_lognorm
# comments_lognorm
#
#                  votes_minus views_lognorm favs_lognorm comments_lognorm
# post_id
# content_len
# comments
# favs
# views
# votes_plus
# votes_minus              1.0
# views_lognorm                          1.0
# favs_lognorm                                        1.0
# comments_lognorm                                                     1.0

# %% [markdown]
# Таким образом устанавливаем, что признаки набора данных
# независимы.

# %% [markdown]
# Проведем еще одно исследование: определим как распределены
# публикации по годам

# %%
df = train_df.copy()
df['published'] = pd.to_datetime(df['published']).dt.year
ss = df['published'].value_counts()
print(ss.sort_index())
# Out:
# published
# 2008     7743
# 2009    10783
# 2010    13091
# 2011    15063
# 2012    15972
# 2013    15537
# 2014    16180
# 2015    23452
# 2016    16316
# Name: count, dtype: int64

# %%
# Данные для построения графика
df = train_df.copy()
df['published'] = pd.to_datetime(df['published']).dt.year  # Преобразование даты в год
ss = df['published'].value_counts()  # Подсчет количества публикаций по годам
ss = ss.sort_index()  # Сортировка по годам

# Построение графика
plt.figure(figsize=(10, 6))
plt.bar(ss.index, ss.values, color='skyblue', edgecolor='black')
plt.xlabel('Год публикации', fontsize=12)
plt.ylabel('Количество публикаций', fontsize=12)
plt.title('Распределение публикаций по годам', fontsize=14)
plt.xticks(rotation=45)  # Поворот подписей на оси X для читаемости
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  # Оптимизация расположения элементов графика
plt.show()

# %%
features = ['author', 'flow', 'domain','title']
train_size = int(0.7 * train_df.shape[0])
print('Размер исходного набора: ', len(train_df), \
      '\nРазмер обучающей подвыборки: ', train_size)
      #отделяем признаки от целевой переменной
X, y = train_df.loc[:, features], train_df['favs_lognorm']
X_test = test_df.loc[:, features]
X_train, X_valid = X.iloc[:train_size, :], X.iloc[train_size:,:]
y_train, y_valid = y.iloc[:train_size], y.iloc[train_size:]
# Out:
# Размер исходного набора:  134137
# Размер обучающей подвыборки:  93895

# %% [markdown]
# Для анализа контента (содержимого файлов howpop_*.jsonlines)
# тспользуем TfidfVectorizer из пакета sklearn. TF-IDF (от англ. TF – term
# frequency, IDF – inverse document frequency) – статистическая мера,
# используемая для оценки важности слова в контексте документа, являющегося
# частью коллекции документов или корпуса. Вес некоторого слова
# пропорционален количеству употребления этого слова в документе, и обратно
# пропорционален частоте употребления слова в других документах коллекции.
# TfidfVectorizer преобразует тексты в матрицу TF-IDF признаков.
# Основные параметры TfidfVectorizer в sklearn: – min_df – при построении словаря слова, которые встречаются реже,
# чем указанное значение, игнорируются; – max_df – при построении словаря слова, которые встречаются чаще,
# чем указанное значение, игнорируются; – analyzer – определяет, строятся ли признаки по словам или по
# символам (буквам); – ngram_range – определяет, формируются ли признаки только из
# отдельных слов или из нескольких слов (в случае с analyzer='char' задает
# количество символов). Например, если указать analyzer='word' и
# ngram_range=(1,3),то признаки будут формироваться из отдельных слов, из
# пар слов и из троек слов; – stop_words – слова, которые игнорируются при построении матрицы.
# Создадим объект TfidfVectorizer и обучим его на данных:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer_title = TfidfVectorizer(min_df=3, max_df=0.3, ngram_range=(1,3))
vX_train_title = vectorizer_title.fit(X_train['title'])
print('vX_train_title.vocabulary_: ', len(vX_train_title.vocabulary_))
vX_valid_title = vectorizer_title.fit(X_valid['title'])
print('vX_train_title.vocabulary_:', len(vX_train_title.vocabulary_))
vX_test_title = vectorizer_title.fit(X_test['title'])
print('vX_train_title.vocabulary_: ', len(vX_train_title.vocabulary_))
X_train_title = vectorizer_title.fit_transform(X_train['title'])
print('X_train_title.shape: ', X_train_title.shape)
X_valid_title = vectorizer_title.transform(X_valid['title'])
print('X_valid_title.shape: ', X_valid_title.shape)
X_test_title = vectorizer_title.transform(X_test['title'])
print('X_test_title.shape: ', X_test_title.shape)
# Out:
# vX_train_title.vocabulary_:  50624
# vX_train_title.vocabulary_: 28528
# vX_train_title.vocabulary_:  2768
# X_train_title.shape:  (93895, 50624)
# X_valid_title.shape:  (40242, 50624)
# X_test_title.shape:  (3990, 50624)

# %% [markdown]
# Получили три словаря и три матрицы TF-IDF. Для доступа к словарям
# можно обратиться к полю vocabulary_ объекта TfidfVectorizer. К этому
# времени объект должен быть обучен – должен быть вызван метод
# fit_transform().

# %%
vectorizer_title.vocabulary_
# Out:
# {'новогодний': 31497,
#  'подарок': 36257,
#  'блоггерам': 14241,
#  'wordpress': 12172,
#  'новогодний подарок': 31499,
#  'сумасшедшие': 45476,
#  'яйца': 50489,
#  'или': 22661,
#  'сервис': 42745,
#  'для': 18811,
#  'отслеживания': 34225,
#  'посетителей': 37373,
#  'или сервис': 22833,
#  'сервис для': 42751,
#  'для отслеживания': 19413,
#  'или сервис для': 22834,
#  'сервис для отслеживания': 42753,
#  'сглаживание': 42460,
#  'шрифтов': 49862,
#  'отрисовка': 34214,
#  'сглаживание шрифтов': 42461,
#  'почему': 37632,
#  'мне': 28231,
#  'не': 30755,
#  'нравится': 31925,
#  'iphone': 5951,
#  'почему мне': 37659,
#  'мне не': 28233,
#  'не нравится': 30851,
#  'всеобщая': 16456,
#  'доступность': 20285,
#  'действии': 18272,
#  'чем': 49165,
#  'суть': 45504,
#  'проекта': 39310,
#  'ru': 9541,
#  'search': 9842,
#  'запускается': 21584,
#  'понедельник': 37201,
#  'mobile': 7315,
#  'выбор': 16759,
#  'способа': 44575,
#  'связи': 42437,
#  'обзор': 32095,
#  'под': 36147,
#  'windows': 11973,
#  'под windows': 36185,
#  'онлайн': 33063,
#  'банкинг': 13661,
#  'оформление': 34332,
#  'рабочего': 40187,
#  'места': 27821,
#  'рабочего места': 40189,
#  'новые': 31597,
#  'скриншоты': 43344,
#  'shell': 9984,
#  'новые скриншоты': 31639,
#  'шанс': 49710,
#  'альтернативных': 13010,
#  'ос': 33434,
#  'кто': 26433,
#  'должен': 19995,
#  'писать': 35235,
#  'js': 6288,
#  'код': 25165,
#  'процессе': 39765,
#  'работы': 40149,
#  'над': 30229,
#  'проектом': 39379,
#  'работы над': 40174,
#  'над проектом': 30234,
#  'работы над проектом': 40175,
#  'top': 11041,
#  '10': 64,
#  'западных': 21471,
#  'стартапов': 44924,
#  'на': 28969,
#  'которые': 26107,
#  'стоит': 45136,
#  'обратить': 32565,
#  'внимание': 15982,
#  '2008': 536,
#  'году': 17617,
#  'top 10': 11042,
#  'стартапов на': 44929,
#  'на которые': 29661,
#  'которые стоит': 26137,
#  'обратить внимание': 32566,
#  '2008 году': 546,
#  'на которые стоит': 29662,
#  'чтение': 49444,
#  'википедии': 15733,
#  'оффлайн': 34339,
#  'исторический': 23719,
#  'кадр': 23928,
#  'оперный': 33172,
#  'мини': 28053,
#  'расследование': 40851,
#  'хочу': 48702,
#  'opera': 8174,
#  'sdk': 9822,
#  'устройств': 47605,
#  'sdk для': 9824,
#  'для устройств': 19679,
#  'снова': 43722,
#  'популярности': 37265,
#  'установка': 47542,
#  'драйвера': 20325,
#  'nvidia': 7978,
#  'ubuntu': 11226,
#  'установка драйвера': 47558,
#  'драйвера для': 20326,
#  'ubuntu 10': 11230,
#  'скрытие': 43377,
#  'всей': 16437,
#  'ветки': 15406,
#  'комментариев': 25343,
#  'если': 20564,
#  'родительский': 41594,
#  'понимание': 37208,
#  'sql': 10358,
#  'всегда': 16423,
#  'бывает': 14696,
#  'первый': 34798,
#  'раз': 40246,
#  'первый раз': 34827,
#  'краткий': 26218,
#  'справочник': 44607,
#  'по': 35659,
#  'краткий справочник': 26221,
#  'справочник по': 44610,
#  'краткий справочник по': 26223,
#  'подсветка': 36478,
#  'синтаксиса': 43050,
#  'кода': 25176,
#  'вашей': 14940,
#  'подсветка синтаксиса': 36483,
#  'кода на': 25189,
#  'на вашей': 29483,
#  'parser': 8426,
#  'практическое': 37933,
#  'применение': 38608,
#  'практическое применение': 37936,
#  'описание': 33179,
#  'более': 14326,
#  '350': 901,
#  'команд': 25296,
#  'линукс': 26869,
#  'google': 4773,
#  'wiki': 11949,
#  'killer': 6405,
#  'открывает': 33989,
#  'новую': 31586,
#  'объявлений': 32735,
#  'программа': 39007,
#  'бесплатно': 13930,
#  'среда': 44682,
#  'оформления': 34336,
#  'вас': 14893,
#  'спасет': 44457,
#  'blackbox': 2273,
#  'win': 11963,
#  'план': 35383,
#  'мульти': 28819,
#  'тач': 45748,
#  'жесты': 20737,
#  'анимация': 13164,
#  'gui': 5129,
#  'план на': 35387,
#  'на windows': 29392,
#  'windows mobile': 12019,
#  'мульти тач': 28820,
#  'на windows mobile': 29395,
#  'бойтесь': 14322,
#  'линукса': 26870,
#  'не бойтесь': 30760,
#  'официальная': 34301,
#  'версия': 15303,
#  'генератор': 17336,
#  'первые': 34783,
#  'впечатления': 16295,
#  'первые впечатления': 34785,
#  'опубликовал': 33294,
#  'фотографии': 48238,
#  'частично': 48976,
#  'спецификации': 44499,
#  'новых': 31776,
#  'моделей': 28443,
#  'телефонов': 45924,
#  'nokia': 7875,
#  'серии': 42833,
#  'новых моделей': 31790,
#  'телефонов nokia': 45926,
#  'запуск': 21558,
#  'плагинов': 35375,
#  'postgresql': 8844,
#  'бесплатный': 13956,
#  'отечественный': 33925,
#  'проигрыватель': 39415,
#  'barcamp': 2110,
#  'последний': 37418,
#  'рабочий': 40202,
#  'день': 18408,
#  'билла': 14138,
#  'гейтса': 17324,
#  'microsoft': 7146,
#  'видео': 15525,
#  'рабочий день': 40203,
#  'билла гейтса': 14139,
#  'объединяя': 32692,
#  'социальные': 44401,
#  'сети': 42921,
#  'возможности': 16112,
#  'социальные сети': 44407,
#  'ru новые': 9571,
#  'новые возможности': 31604,
#  'top4top': 11047,
#  'открыт': 34020,
#  'за': 20841,
#  'контент': 25749,
#  'долгожданное': 19988,
#  'открытие': 34038,
#  'создатель': 44140,
#  'будет': 14576,
#  'работать': 40091,
#  'будет работать': 14599,
#  'работать на': 40095,
#  'на google': 29144,
#  'будет работать на': 14600,
#  'textmate': 10860,
#  'средствами': 44711,
#  'gedit': 4642,
#  'улучшение': 47156,
#  'поиска': 36635,
#  'улучшение поиска': 47157,
#  'дела': 18310,
#  'давно': 17953,
#  'дней': 19732,
#  'macheist': 6874,
#  'ii': 5625,
#  'четвертая': 49332,
#  'миссия': 28186,
#  'бесплатные': 13947,
#  'программы': 39153,
#  'бесплатные программы': 13955,
#  'что': 49450,
#  'лучше': 27094,
#  'сервера': 42700,
#  'freebsd': 4480,
#  'mac': 6851,
#  'os': 8294,
#  'server': 9906,
#  'что лучше': 49529,
#  'лучше для': 27097,
#  'для сервера': 19579,
#  'freebsd или': 4484,
#  'mac os': 6858,
#  'что лучше для': 49530,
#  'web': 11771,
#  'четвертой': 49335,
#  'мировой': 28164,
#  'войне': 16161,
#  'будут': 14614,
#  'воевать': 16071,
#  'web или': 11806,
#  'как': 23965,
#  'эпоха': 50218,
#  'ит': 23802,
#  'com': 2855,
#  'стартап': 44884,
#  'то': 46353,
#  'мог': 28416,
#  'стать': 45016,
#  'стартап для': 44886,
#  'то чем': 46363,
#  'лучшие': 27112,
#  'студии': 45379,
#  'нет': 31262,
#  'или нет': 22775,
#  'бесплатная': 13920,
#  'телефонная': 45910,
#  'связь': 42454,
#  'контекстной': 25742,
#  'рекламой': 41262,
#  'php': 8605,
#  'библиотека': 14053,
#  'jquery': 6263,
#  'php библиотека': 8619,
#  'библиотека для': 14054,
#  'для jquery': 18935,
#  'php библиотека для': 8620,
#  'пора': 37292,
#  'покупать': 36761,
#  'бренды': 14543,
#  'перевод': 34860,
#  '50': 1027,
#  'opera 50': 8191,
#  'open': 8120,
#  'forum': 4413,
#  'europe': 3988,
#  'поддержала': 36331,
#  'software': 10205,
#  'opera software': 8208,
#  'китае': 24905,
#  'вводят': 15011,
#  'государственные': 17751,
#  'лицензии': 26913,
#  'сервисов': 42795,
#  'ugc': 11280,
#  'для сервисов': 19583,
#  '04': 33,
#  'hardy': 5204,
#  'есть': 20584,
#  'чего': 49106,
#  'ждать': 20663,
#  'ubuntu 04': 11227,
#  'чего ждать': 49109,
#  'исследование': 23691,
#  'facebook': 4110,
#  'facebook com': 4111,
#  'вот': 16275,
#  'так': 45673,
#  'лого': 27019,
#  'вот так': 16276,
#  'локализация': 27042,
#  'drupal': 3681,
#  'риа': 41489,
#  'новости': 31558,
#  'видел': 15521,
#  'никто': 31348,
#  'риа новости': 41490,
#  'то что': 46364,
#  'что не': 49552,
#  'не видел': 30774,
#  'то что не': 46367,
#  'небольшой': 30954,
#  'эксперимент': 50001,
#  'translate': 11122,
#  'google translate': 4898,
#  'ces': 2579,
#  'benq': 2180,
#  'представляет': 38097,
#  'internet': 5834,
#  'device': 3437,
#  'wifi': 11936,
#  'поддержкой': 36354,
#  'сетей': 42918,
#  '5g': 1069,
#  'анатолий': 13121,
#  'эта': 50243,
#  'cakephp': 2461,
#  'beta': 2185,
#  'устранение': 47590,
#  'фоновых': 48160,
#  'картинок': 24668,
#  'ie6': 5598,
#  'usb': 11389,
#  'фото': 48222,
#  'asus': 1940,
#  'eee': 3792,
#  'pc': 8467,
#  'дюймовым': 20443,
#  'экраном': 49985,
#  'первые фото': 34795,
#  'asus eee': 1941,
#  'eee pc': 3797,
#  'дюймовым экраном': 20445,
#  'asus eee pc': 1944,
#  'миллион': 28015,
#  'дайджест': 17966,
#  'месяц': 27843,
#  'стартап на': 44894,
#  'на миллион': 29708,
#  'за месяц': 20972,
#  'стартап на миллион': 44895,
#  'дождь': 19910,
#  'снег': 43685,
#  'появились': 37769,
#  'maps': 6959,
#  'google maps': 4849,
#  'на google maps': 29149,
#  'официальный': 34321,
#  'холивар': 48592,
#  'ищет': 23869,
#  'таланты': 45725,
#  'поощряет': 37225,
#  'ищет таланты': 23872,
#  'платформа': 35537,
#  'американском': 13041,
#  'рынке': 41917,
#  'качественный': 24763,
#  'хостинг': 48642,
#  'миф': 28192,
#  'реальность': 41035,
#  'миф или': 28193,
#  'или реальность': 22826,
#  'миф или реальность': 28194,
#  'закончился': 21349,
#  'ruby': 9584,
#  'logo': 6771,
#  'contest': 2980,
#  'верстальщика': 15350,
#  'часть': 49010,
#  'jquery для': 6275,
#  'для верстальщика': 19151,
#  'советский': 43891,
#  'гарнитура': 17274,
#  'jawbone': 6214,
#  '44': 1003,
#  'миллиона': 28020,
#  'долларов': 20017,
#  'миллиона долларов': 28021,
#  'долларов за': 20020,
#  'миллиона долларов за': 28022,
#  'какая': 24476,
#  'javascript': 6180,
#  'лучшая': 27093,
#  'javascript библиотека': 6193,
#  'apple': 1729,
#  'платформе': 35550,
#  'intel': 5778,
#  'энтузиастов': 50208,
#  'производства': 39440,
#  'alienware': 1417,
#  'платформе intel': 35553,
#  'finereader': 4236,
#  'сделают': 42512,
#  'данные': 18019,
#  'пользователей': 36983,
#  'google facebook': 4828,
#  'данные пользователей': 18028,
#  'будущее': 14622,
#  'веб': 15023,
#  'стандартов': 44837,
#  'будущее веб': 14624,
#  'веб стандартов': 15110,
#  'xobni': 12327,
#  'новый': 31652,
#  'сан': 42148,
#  'франциско': 48291,
#  'сан франциско': 42149,
#  'im': 5636,
#  'history': 5319,
#  'показ': 36710,
#  'рекламы': 41265,
#  'adsense': 1332,
#  'стал': 44789,
#  'gmail': 4736,
#  'imap': 5656,
#  'теперь': 46005,
#  'русски': 41847,
#  'теперь по': 46046,
#  'по русски': 35948,
#  'теперь по русски': 46047,
#  'работа': 40026,
#  'командной': 25309,
#  'строкой': 45329,
#  'быстрее': 14730,
#  'ie': 5594,
#  'десять': 18493,
#  'блогера': 14246,
#  'релиз': 41311,
#  'kde': 6362,
#  'релиз kde': 41321,
#  'забавный': 21082,
#  'глюк': 17559,
#  'вкусные': 15888,
#  'меню': 27781,
#  'браузеры': 14534,
#  'acid': 1248,
#  'грядет': 17908,
#  'война': 16159,
#  'браузеров': 14525,
#  'война браузеров': 16160,
#  'linux': 6656,
#  'организации': 33382,
#  'пиратство': 35220,
#  'сеть': 42955,
#  'доходов': 20315,
#  'задача': 21245,
#  'про': 38850,
#  'две': 18151,
#  'задача про': 21253,
#  'цветовые': 48791,
#  'studio': 10565,
#  'vs': 11672,
#  'adobe': 1313,
#  'studio vs': 10583,
#  'vs adobe': 11675,
#  'поговорим': 36129,
#  'стартапах': 44910,
#  'дизайне': 18658,
#  'самое': 42061,
#  'главное': 17490,
#  'же': 20673,
#  'тратить': 46605,
#  'деньги': 18436,
#  'или снова': 22840,
#  'самое главное': 42063,
#  'на что': 30104,
#  'что же': 49510,
#  'тратить деньги': 46606,
#  'встречайте': 16549,
#  'acid3': 1249,
#  'автоматизация': 12596,
#  'человек': 49135,
#  'мечты': 27940,
#  'мечты реальность': 27942,
#  'импорт': 22928,
#  'публикаций': 39899,
#  'из': 22268,
#  'вы': 16674,
#  'пост': 37474,
#  'хабре': 48454,
#  'как вы': 24021,
#  'на хабре': 30089,
#  'hello': 5255,
#  'world': 12192,
#  'air': 1375,
#  'hello world': 5256,
#  'adobe air': 1314,
#  'почувствуй': 37747,
#  'превращение': 37955,
#  'гаджет': 17234,
#  'векторизация': 15199,
#  'логотипов': 27027,
#  'иконки': 22653,
#  'хабрахабра': 48447,
#  'приближение': 38285,
#  'суперхабра': 45494,
#  'иконки для': 22654,
#  'для хабрахабра': 19692,
#  'expo': 4064,
#  'ссылки': 44746,
#  'доверия': 19890,
#  'rss': 9525,
#  'yahoo': 12382,
#  'pipes': 8709,
#  'yahoo pipes': 12386,
#  'выиграй': 16854,
#  'nintendo': 7840,
#  'wii': 11947,
#  'плюс': 35650,
#  'guitar': 5140,
#  'hero': 5267,
#  'iii': 5627,
#  'nintendo wii': 7843,
#  'guitar hero': 5141,
#  'профиль': 39738,
#  'инвестора': 22971,
#  'венчурный': 15235,
#  'фонд': 48135,
#  'venture': 11502,
#  'partners': 8436,
#  'венчурный фонд': 15237,
#  'venture partners': 11503,
#  'история': 23723,
#  'успеха': 47506,
#  'стартапа': 44904,
#  'история успеха': 23764,
#  'портативный': 37320,
#  'паяльник': 34714,
#  'смартфон': 43576,
#  'платформы': 35577,
#  'android': 1503,
#  'сделали': 42483,
#  'китайцы': 24926,
#  'первый смартфон': 34832,
#  'смартфон для': 43584,
#  'для платформы': 19438,
#  'google android': 4785,
#  'дома': 20045,
#  'iphone для': 5969,
#  'для дома': 19207,
#  'интервью': 23192,
#  'gizmodo': 4720,
#  'практический': 37923,
#  'css': 3096,
#  'все': 16370,
#  'css js': 3102,
#  'net': 7696,
#  'мобильный': 28368,
#  'укради': 47119,
#  'этот': 50331,
#  'фильм': 48011,
#  'пираты': 35223,
#  'платят': 35598,
#  'они': 33059,
#  'get': 4682,
#  'time': 10946,
#  'machine': 6875,
#  'time machine': 10948,
#  'сновидений': 43727,
#  'вперед': 16288,
#  'переход': 35017,
#  'icq': 5557,
#  'jabber': 6111,
#  'вперед будущее': 16289,
#  'на jabber': 29204,
#  'конструктор': 25696,
#  'создания': 44111,
#  'зависимых': 21146,
#  'приложений': 38490,
#  'стиле': 45103,
#  'конструктор для': 25698,
#  'для создания': 19609,
#  'blitz': 2287,
#  'templates': 10826,
#  'прототипирование': 39703,
#  'сайтов': 42001,
#  'собирая': 43812,
#  'web сайтов': 11829,
#  'исходники': 23780,
#  'sim': 10031,
#  'city': 2710,
#  'открыты': 34065,
#  'gnu': 4748,
#  'gpl': 5050,
#  'gnu gpl': 4749,
#  'добавлены': 19849,
#  'очередной': 34400,
#  'изображений': 22575,
#  'строят': 45338,
#  'свои': 42345,
#  'cdn': 2541,
#  'microsoft google': 7162,
#  'нужно': 31950,
#  'держать': 18472,
#  'открытым': 34074,
#  'проигрывание': 39412,
#  'музыки': 28807,
#  'кино': 24884,
#  'приставке': 38788,
#  'на приставке': 29873,
#  'itunes': 6093,
#  'safari': 9665,
#  'for': 4366,
#  'дальше': 18013,
#  'for windows': 4389,
#  'что дальше': 49484,
#  'macworld': 6885,
#  'прямая': 39848,
#  'трансляция': 46575,
#  'прямая трансляция': 39849,
#  'знаете': 21929,
#  'что вы': 49472,
#  'вы знаете': 16697,
#  'что вы знаете': 49474,
#  'европейская': 20466,
#  'комиссия': 25340,
#  'начала': 30637,
#  'два': 18132,
#  'расследования': 40853,
#  'sprites': 10349,
#  'знали': 21965,
#  'но': 31374,
#  'боялись': 14465,
#  'спросить': 44624,
#  'css sprites': 3105,
#  'все что': 16417,
#  'вы знали': 16698,
#  'но боялись': 31376,
#  'боялись спросить': 14466,
#  'все что вы': 16419,
#  'но боялись спросить': 31377,
#  'девять': 18261,
#  'доказательств': 19916,
#  'природы': 38771,
#  'mp3': 7465,
#  'player': 8760,
#  'относитесь': 34159,
#  'компании': 25412,
#  'вы относитесь': 16717,
#  'компании apple': 25413,
#  'как вы относитесь': 24024,
#  'пакет': 34470,
#  'amazon': 1443,
#  'товаров': 46382,
#  'млрд': 28225,
#  'товаров на': 46384,
#  'на млрд': 29715,
#  'таки': 45698,
#  'нужна': 31944,
#  'ли': 26773,
#  'полная': 36864,
#  'кросс': 26337,
#  'все таки': 16413,
#  'нужна ли': 31945,
#  'media': 7055,
#  'explorer': 4054,
#  'составе': 44284,
#  'конкуренция': 25614,
#  'media player': 7058,
#  'internet explorer': 5836,
#  'личной': 26952,
#  'хабраленты': 48431,
#  'без': 13735,
#  'без комментариев': 13763,
#  'функциональный': 48379,
#  'клон': 25049,
#  'lightbox': 6616,
#  'сбор': 42189,
#  'mini': 7266,
#  'для opera': 18988,
#  'opera mini': 8198,
#  'самым': 42131,
#  'популярным': 37271,
#  'устройством': 47635,
#  'стал самым': 44799,
#  'самым популярным': 42132,
#  'стал самым популярным': 44800,
#  'новое': 31507,
#  'xerox': 12306,
#  'новое лого': 31513,
#  'бросает': 14562,
#  'вызов': 16844,
#  'хостингу': 48662,
#  's3': 9655,
#  'amazon s3': 1454,
#  'дата': 18099,
#  'центры': 48862,
#  'апреле': 13288,
#  'дата центры': 18110,
#  'мечта': 27936,
#  'слонов': 43509,
#  'часто': 48992,
#  'пользуетесь': 37048,
#  'как часто': 24455,
#  'часто вы': 48993,
#  'вы пользуетесь': 16723,
#  'как часто вы': 24456,
#  'часто вы пользуетесь': 48994,
#  'starbucks': 10445,
#  'браузер': 14486,
#  'кому': 25555,
#  'веб браузер': 15028,
#  'обновилась': 32398,
#  'до': 19776,
#  'версии': 15273,
#  'до версии': 19799,
#  'кроссбраузерное': 26345,
#  'трудности': 46750,
#  'отрисовки': 34215,
#  'macbook': 6870,
#  'pro': 8914,
#  'мышкой': 28944,
#  'если вас': 20568,
#  'macbook pro': 6873,
#  'пользуетесь ли': 37050,
#  'ли вы': 26786,
#  'пользуетесь ли вы': 37051,
#  'довольны': 19896,
#  'вы довольны': 16690,
#  'необычные': 31165,
#  'мониторы': 28670,
#  'от': 33606,
#  'nec': 7675,
#  'сумка': 45478,
#  'сделки': 42519,
#  '2007': 534,
#  'области': 32306,
#  'technology': 10806,
#  'машинок': 27622,
#  'автокадабры': 12585,
#  'семь': 42635,
#  'лет': 26721,
#  'семь лет': 42636,
#  'фактов': 47907,
#  'об': 31997,
#  '10 фактов': 158,
#  'фактов об': 47908,
#  'актуально': 12922,
#  'рунете': 41836,
#  'сообщества': 44240,
#  'владельцев': 15893,
#  'сколько': 43280,
#  'сих': 43208,
#  'пор': 37290,
#  'перешел': 35043,
#  'мак': 27271,
#  'до сих': 19824,
#  'сих пор': 43209,
#  'пор не': 37291,
#  'перешел на': 35044,
#  'на мак': 29691,
#  'до сих пор': 19825,
#  'сих пор не': 43210,
#  'куда': 26479,
#  'идут': 22259,
#  'три': 46702,
#  'бизнес': 14074,
#  'модели': 28444,
#  'могут': 28426,
#  'принести': 38694,
#  'миллиарды': 28014,
#  'бизнес модели': 14093,
#  'которые могут': 26121,
#  'sun': 10626,
#  'купила': 26502,
#  'mysql': 7600,
#  'хабра': 48415,
#  'ice': 5533,
#  'первая': 34722,
#  'неконференция': 31093,
#  'pgp': 8545,
#  'стали': 44806,
#  'дружелюбнее': 20375,
#  'ноутбук': 31868,
#  'большой': 14400,
#  'компьютер': 25499,
#  'рабочем': 40196,
#  'месте': 27828,
#  'компьютер на': 25507,
#  'на рабочем': 29898,
#  'рабочем месте': 40197,
#  'на рабочем месте': 29899,
#  'рунет': 41829,
#  'проблем': 38895,
#  'яндекс': 50505,
#  'директе': 18721,
#  'из за': 22358,
#  'обновление': 32413,
#  'ipod': 5995,
#  'touch': 11069,
#  'платное': 35520,
#  'почему же': 37649,
#  'ipod touch': 5999,
#  'вводная': 15008,
#  'для стартапов': 19630,
#  'стартапов от': 44930,
#  'курс': 26514,
#  'обучения': 32621,
#  'курс обучения': 26524,
#  'недостатков': 31034,
#  'нового': 31474,
#  'ноутбука': 31881,
#  'apple macbook': 1746,
#  'macbook air': 6871,
#  'apple macbook air': 1747,
#  'среду': 44725,
#  'внимание на': 15984,
#  '90': 1166,
#  'минут': 28104,
#  'keynote': 6388,
#  '60': 1074,
#  'секунд': 42580,
#  '90 минут': 1167,
#  'за 60': 20907,
#  '60 секунд': 1081,
#  'за 60 секунд': 20908,
#  'несколько': 31219,
#  'глобально': 17536,
#  'мыслей': 28929,
#  'об apple': 31999,
#  'xss': 12361,
#  'яндексе': 50582,
#  'xss на': 12362,
#  'на яндексе': 30140,
#  'нестандартное': 31252,
#  'использование': 23573,
#  'поисковых': 36688,
#  'нестандартное использование': 31253,
#  'советов': 43881,
#  'новичку': 31468,
#  '10 советов': 153,
#  'стив': 45082,
#  'джобс': 18575,
#  '08': 54,
#  'секундах': 42584,
#  'стив джобс': 45087,
#  'улучшаем': 47152,
#  'навигацию': 30190,
#  'reader': 9299,
#  'google reader': 4877,
#  'конгресса': 25584,
#  'flickr': 4338,
#  'библиотека конгресса': 14056,
#  'на flickr': 29128,
#  'бага': 13548,
#  'firefox': 4245,
#  'философии': 48005,
#  'чайников': 48939,
#  'для чайников': 19704,
#  'stand': 10432,
#  'alone': 1428,
#  'russian': 9628,
#  'tumblr': 11163,
#  'stand alone': 10433,
#  'трюки': 46760,
#  'динамический': 18701,
#  'favicon': 4170,
#  'чтения': 49447,
#  'лент': 26703,
#  'для чтения': 19710,
#  'rss лент': 9529,
#  'девочка': 18251,
#  'подросток': 36467,
#  'создала': 44011,
#  'год': 17587,
#  'миллион долларов': 28016,
#  'долларов год': 20019,
#  'очередное': 34398,
#  'очередное обновление': 34399,
#  'обновление по': 32439,
#  'червь': 49231,
#  'меньше': 27779,
#  'лидирует': 26838,
#  'xp': 12330,
#  'windows xp': 12082,
#  'toshiba': 11060,
#  'показала': 36714,
#  'umpc': 11299,
#  'топливных': 46475,
#  'элементах': 50158,
#  'на топливных': 30055,
#  'топливных элементах': 46476,
#  'на топливных элементах': 30056,
#  'электронные': 50125,
#  'книги': 25098,
#  'читалки': 49422,
#  'электронные книги': 50127,
#  'что нового': 49558,
#  'source': 10267,
#  'библиотеку': 14068,
#  'open source': 8126,
#  'source javascript': 10270,
#  'javascript библиотеку': 6196,
#  'open source javascript': 8128,
#  'средства': 44705,
#  'разработки': 40543,
#  'нас': 30472,
#  'ждёт': 20672,
#  'средства разработки': 44710,
#  'что нас': 49550,
#  'archlinux': 1834,
#  'создание': 44022,
#  'своей': 42337,
#  'сборки': 42212,
#  'вопрос': 16197,
#  'создание своей': 44091,
#  'сборки windows': 42213,
#  'опять': 33367,
#  'карму': 24631,
#  'где': 17287,
#  'идеи': 22216,
#  'при': 38224,
#  'создании': 44104,
#  'дизайна': 18650,
#  'сайта': 41966,
#  'где вы': 17289,
#  'при создании': 38278,
#  'дизайна сайта': 18655,
#  'спасите': 44460,
#  'приходит': 38801,
#  'смену': 43627,
#  'blackberry': 2265,
#  'крупных': 26416,
#  'приходит на': 38802,
#  'на смену': 30002,
#  'презентация': 38132,
#  'проектированию': 39351,
#  'деловых': 18370,
#  'социальных': 44418,
#  'проекта по': 39323,
#  'по проектированию': 35912,
#  'социальных сетей': 44422,
#  'сенсорным': 42651,
#  'управлением': 47351,
#  'флэшка': 48123,
#  'домино': 20132,
#  'закрыл': 21364,
#  'ты': 46807,
#  'тег': 45795,
#  'ли ты': 26825,
#  'my': 7583,
#  'game': 4591,
#  'хабрахабр': 48446,
#  'виджет': 15679,
#  'музей': 28782,
#  'компьютерной': 25524,
#  'техники': 46223,
#  'идея': 22247,
#  'музей компьютерной': 28784,
#  'компьютерной техники': 25530,
#  'ещё': 20632,
#  'больше': 14349,
#  'компьютеров': 25544,
#  'борту': 14430,
#  'ещё больше': 20635,
#  'linux на': 6689,
#  'на борту': 29476,
#  'юзабилити': 50389,
#  'бюллетень': 14814,
#  'выпуск': 16914,
#  '14': 325,
#  'юзабилити бюллетень': 50390,
#  'бюллетень выпуск': 14815,
#  'выпуск 14': 16920,
#  'юзабилити бюллетень выпуск': 50391,
#  'проблемы': 38909,
#  ...}

# %% [markdown]
# Построим TF-IDF-матрицы для этих же признаков, но с
# использованием параметра analyzer='char'

# %%
vectorizer_title_ch = TfidfVectorizer(analyzer='char')

vX_train_title_ch = vectorizer_title_ch.fit(X_train['title'])
print('vX_train_title_ch.vocabulary_: ', len(vX_train_title_ch.vocabulary_))
vX_valid_title_ch = vectorizer_title_ch.fit(X_valid['title'])
print('vX_valid_title_ch.vocabulary_: ', len(vX_valid_title_ch.vocabulary_))
vX_test_title_ch = vectorizer_title_ch.fit(X_test['title'])
print('vX_test_title_ch.vocabulary_:', len(vX_test_title_ch.vocabulary_))
X_train_title_ch = vectorizer_title_ch.fit_transform(X_train['title'])
print('X_train_title_ch.shape: ', X_train_title_ch.shape)
X_valid_title_ch = vectorizer_title_ch.transform(X_valid['title'])
print('X_valid_title_ch.shape: ', X_valid_title_ch.shape)
X_test_title_ch = vectorizer_title_ch.transform(X_test['title'])
print('X_test_title_ch.shape: ', X_test_title_ch.shape)
# Out:
# vX_train_title_ch.vocabulary_:  218
# vX_valid_title_ch.vocabulary_:  165
# vX_test_title_ch.vocabulary_: 136
# X_train_title_ch.shape:  (93895, 218)
# X_valid_title_ch.shape:  (40242, 218)
# X_test_title_ch.shape:  (3990, 218)

# %% [markdown]
# Для обработки остальных признаков будем использовать
# DictVectorizer из sklearn. Признаки ['author', 'flow', 'domain'] имеют
# категориальную природу, для них TfidfVectorizer неприменим.

# %%
from sklearn.feature_extraction import DictVectorizer
feats = ['author', 'flow', 'domain', 'title']
vectorizer_feats = DictVectorizer()

tmp_dict_train = X_train[feats].fillna('-').T.to_dict().values()
tmp_dict_valid = X_valid[feats].fillna('-').T.to_dict().values()
tmp_dict_test = X_test[feats].fillna('-').T.to_dict().values()

# %%
X_train_feats = vectorizer_feats.fit_transform(tmp_dict_train)
X_valid_feats = vectorizer_feats.transform(tmp_dict_valid)
X_test_feats = vectorizer_feats.transform(tmp_dict_test)
print(X_train_feats.shape)
print(X_valid_feats.shape)
print(X_test_feats.shape)
# Out:
# (93895, 111482)
# (40242, 111482)
# (3990, 111482)

# %% [markdown]
# Выполним объединение полученных матриц:

# %%
# объединение матриц, построенных на предыдущих этапах
X_train_new = scipy.sparse.hstack([X_train_title,\
                                   X_train_feats,\
                                   X_train_title_ch])
X_valid_new = scipy.sparse.hstack([X_valid_title,\
                                   X_valid_feats,\
                                   X_valid_title_ch])
X_test_new = scipy.sparse.hstack([X_test_title,\
                                  X_test_feats,\
                                  X_test_title_ch])
print(X_train_new.shape)
print(X_valid_new.shape)
print(X_test_new.shape)
# Out:
# (93895, 162324)
# (40242, 162324)
# (3990, 162324)

# %% [markdown]
# Для обучения выбрана линейная модель регрессии с L2
# регуляризацией.

# %%
# %%time
model_1 = Ridge(alpha=.1, random_state=1)
model_1.fit(X_train_new, y_train)
# Out:
# CPU times: user 19.5 s, sys: 14.1 s, total: 33.6 s
# Wall time: 20.4 s
# Ridge(alpha=0.1, random_state=1)

# %%
train_preds1 = model_1.predict(X_train_new)
valid_preds1 = model_1.predict(X_valid_new)
print('Ошибка на трейне: ', mean_squared_error(y_train, train_preds1))
print('Ошибка на тесте: ', mean_squared_error(y_valid, valid_preds1))
# Out:
# Ошибка на трейне:  0.0033498668127804505
# Ошибка на тесте:  0.6982987113454213

# %% [markdown]
# Выполним обучение еще одной модели и проверим ошибки:

# %%
# %%time
model_2 = Ridge(alpha=1.0, random_state=1)
model_2.fit(X_train_new, y_train)
# Out:
# CPU times: user 8.03 s, sys: 5.46 s, total: 13.5 s
# Wall time: 10.2 s
# Ridge(random_state=1)

# %%
train_preds2 = model_2.predict(X_train_new)
valid_preds2 = model_2.predict(X_valid_new)
print('Ошибка на трейне: ', mean_squared_error(y_train, train_preds2))
print('Ошибка на тесте: ', mean_squared_error(y_valid, valid_preds2))
# Out:
# Ошибка на трейне:  0.08633264425668048
# Ошибка на тесте:  0.6840061221431166

# %% [markdown]
# ## Индивидуальное задание
#
# 1. Выполните построение модели классификации на основе дерева классификации. В ходе решения задачи необходимо решить следующие подзадачи:
# 1.2 Построение логического классификатора с заданием max_depth (максимальной  глубины) и max_features (максимального количества признаков) пользователем(установить любые); визуализация дерева решений для выбранных исследователем параметров (в формате .png)
# 2.3 Вычисление оценки cross validation (MSE) для различнх значений max_depth (построить график зависимости);
# 2.4 Вычисление оценки cross validation (MSE) для различнх значений max_features (построить график зависимости);
# 2.5 Вычислите оптимальные значения max_depth и max_features. Обоснуйте свой выбор. Продемонстрируйте использование полученного классификатора.
# 2.6 Выведите дерево в формате .png;
# 2.7 Выведите решающие границы полученной модели.

# %% [markdown]
# ## Шаг 1. Загрузка библиотеки, нормализация данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# Загрузка данных
data = pd.read_csv('diabetes.csv')

# Разделение данных на признаки (X) и целевую переменную (y)
X = data.drop('Outcome', axis=1)
y = data['Outcome']

# Нормализация данных
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Разделение на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Шаг 2.1 Построение логического классификатора с max_depth и max_features

# %%
max_depth = 3  # Пример значения для максимальной глубины
max_features = 4  # Пример значения для максимального числа признаков
classifier = DecisionTreeClassifier(max_depth=max_depth, max_features=max_features, random_state=42)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, max_features=4, random_state=42)

# %% [markdown]
# ## Шаг 2.2 Визуализация дерева решений

# %%
plt.figure(figsize=(12,8))
plot_tree(classifier, filled=True, feature_names=X.columns, class_names=['No', 'Yes'], rounded=True)
plt.savefig('decision_tree.png')
plt.show()

# %% [markdown]
# ## Шаг 2.3 Cross-validation для max_depth

# %%
depth_range = range(1, 21)
mse_depth = []
for depth in depth_range:
    model = DecisionTreeClassifier(max_depth=depth, random_state=42)
    scores = cross_val_score(model, X_scaled, y, cv=10, scoring='neg_mean_squared_error')
    mse_depth.append(-scores.mean())  # Преобразуем в положительное значение MSE

plt.plot(depth_range, mse_depth)
plt.title('Cross-validation MSE для различных max_depth')
plt.xlabel('max_depth')
plt.ylabel('MSE')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Шаг 2.3 Cross-validation для max_features

# %%
features_range = range(1, X.shape[1] + 1)
mse_features = []
for features in features_range:
    model = DecisionTreeClassifier(max_features=features, random_state=42)
    scores = cross_val_score(model, X_scaled, y, cv=10, scoring='neg_mean_squared_error')
    mse_features.append(-scores.mean())  # Преобразуем в положительное значение MSE

plt.plot(features_range, mse_features)
plt.title('Cross-validation MSE для различных max_features')
plt.xlabel('max_features')
plt.ylabel('MSE')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Шаг 2.4 Оптимальные значения max_depth и max_features

# %%
optimal_depth = depth_range[np.argmin(mse_depth)]
optimal_features = features_range[np.argmin(mse_features)]
print(f"Оптимальные значения: max_depth = {optimal_depth}, max_features = {optimal_features}")
# Out:
# Оптимальные значения: max_depth = 2, max_features = 8

# %% [markdown]
# ## Шаг 2.5 Визуализация дерева для оптимальных значений

# %%
classifier_optimal = DecisionTreeClassifier(max_depth=optimal_depth, max_features=optimal_features, random_state=42)
classifier_optimal.fit(X_train, y_train)
plt.figure(figsize=(12,8))
plot_tree(classifier_optimal, filled=True, feature_names=X.columns, class_names=['No', 'Yes'], rounded=True)
plt.savefig('optimal_decision_tree.png')
plt.show()

# %% [markdown]
# ## Шаг 2.6 Визуализация решающих границ для признаков 'BMI' и 'Glucose'

# %%
X_train_2d = X_train[:, [5, 1]]  # 'BMI' и 'Glucose' имеют индексы 5 и 1 в датафрейме
X_test_2d = X_test[:, [5, 1]]

model_2d = DecisionTreeClassifier(max_depth=optimal_depth, max_features=optimal_features, random_state=42)
model_2d.fit(X_train_2d, y_train)

# Создаем сетку для визуализации
x_min, x_max = X_train_2d[:, 0].min() - 1, X_train_2d[:, 0].max() + 1
y_min, y_max = X_train_2d[:, 1].min() - 1, X_train_2d[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# Предсказания для всех точек в сетке
Z = model_2d.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Визуализация решающих границ
plt.contourf(xx, yy, Z, alpha=0.8)
plt.scatter(X_train_2d[:, 0], X_train_2d[:, 1], c=y_train, edgecolors='k', marker='o', s=50)
plt.title('Решающие границы для признаков "BMI" и "Glucose"')
plt.xlabel('BMI')
plt.ylabel('Glucose')
plt.show()
